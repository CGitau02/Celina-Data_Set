# %% [markdown]
# <a href="https://colab.research.google.com/github/CGitau02/Data_Set_Tasks/blob/main/Student_Data_Sheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
student_data =files.upload ()
# Out:
#      <input type="file" id="files-32a2cce2-3939-413a-a55a-9ef5347188e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32a2cce2-3939-413a-a55a-9ef5347188e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
student_data = pd.read_csv ('student.csv')

# %%
student_data
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78     NaN
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
student_data [student_data ['class'] == 'Four']
# Out:
#     id         name class  mark  gender
# 0    1     John Deo  Four    75  female
# 3    4   Krish Star  Four    60  female
# 4    5    John Mike  Four    60  female
# 5    6    Alex John  Four    55    male
# 9   10     Big John  Four    55  female
# 15  16        Gimmy  Four    88    male
# 20  21   Babby John  Four    69  female
# 30  31  Marry Toeey  Four    88    male

# %%
student_data['passed'] = student_data ['mark'] >= 60
print ('passed')
# Out:
# passed

# %%
student_data
# Out:
#     id         name  class  mark  gender  passed
# 0    1     John Deo   Four    75  female    True
# 1    2     Max Ruin  Three    85    male    True
# 2    3       Arnold  Three    55    male   False
# 3    4   Krish Star   Four    60  female    True
# 4    5    John Mike   Four    60  female    True
# 5    6    Alex John   Four    55    male   False
# 6    7  My John Rob  Fifth    78    male    True
# 7    8       Asruid   Five    85    male    True
# 8    9      Tes Qry    Six    78     NaN    True
# 9   10     Big John   Four    55  female   False
# 10  11       Ronald    Six    89  female    True
# 11  12        Recky    Six    94  female    True
# 12  13          Kty  Seven    88  female    True
# 13  14         Bigy  Seven    88  female    True
# 14  15     Tade Row    NaN    88    male    True
# 15  16        Gimmy   Four    88    male    True
# 16  17        Tumyu    Six    54    male   False
# 17  18        Honny   Five    75    male    True
# ...

# %%
student_data ['passed'] = student_data ['mark'] >= 60
print

# %%
student_data.rename (columns = {'mark' : 'score'}, inplace = True)
print('score')
# Out:
# score

# %%
student_data
# Out:
#     id         name  class  score  gender  passed
# 0    1     John Deo   Four     75  female    True
# 1    2     Max Ruin  Three     85    male    True
# 2    3       Arnold  Three     55    male   False
# 3    4   Krish Star   Four     60  female    True
# 4    5    John Mike   Four     60  female    True
# 5    6    Alex John   Four     55    male   False
# 6    7  My John Rob  Fifth     78    male    True
# 7    8       Asruid   Five     85    male    True
# 8    9      Tes Qry    Six     78     NaN    True
# 9   10     Big John   Four     55  female   False
# 10  11       Ronald    Six     89  female    True
# 11  12        Recky    Six     94  female    True
# 12  13          Kty  Seven     88  female    True
# 13  14         Bigy  Seven     88  female    True
# 14  15     Tade Row    NaN     88    male    True
# 15  16        Gimmy   Four     88    male    True
# 16  17        Tumyu    Six     54    male   False
# 17  18        Honny   Five     75    male    True
# ...

# %%
student_data.drop (columns = ['passed'], inplace =True )

# %%
student_data
# Out:
#     id         name  class  score  gender
# 0    1     John Deo   Four     75  female
# 1    2     Max Ruin  Three     85    male
# 2    3       Arnold  Three     55    male
# 3    4   Krish Star   Four     60  female
# 4    5    John Mike   Four     60  female
# 5    6    Alex John   Four     55    male
# 6    7  My John Rob  Fifth     78    male
# 7    8       Asruid   Five     85    male
# 8    9      Tes Qry    Six     78     NaN
# 9   10     Big John   Four     55  female
# 10  11       Ronald    Six     89  female
# 11  12        Recky    Six     94  female
# 12  13          Kty  Seven     88  female
# 13  14         Bigy  Seven     88  female
# 14  15     Tade Row    NaN     88    male
# 15  16        Gimmy   Four     88    male
# 16  17        Tumyu    Six     54    male
# 17  18        Honny   Five     75    male
# 18  19        Tinny   Nine     18    male
# 19  20       Jackly   Nine     65  female
# 20  21   Babby John   Four     69  female
# ...

# %%
student_data ['score'].mean ()
# Out:
# np.float64(74.65714285714286)

# %%
pivot_table = pd.pivot_table (student_data, values = 'score', index = 'class', aggfunc = 'mean')
print (pivot_table)
# Out:
#            score
# class
# Eight  79.000000
# Fifth  78.000000
# Five   80.000000
# Four   68.750000
# Nine   41.500000
# Seven  77.600000
# Six    82.571429
# Three  73.666667

# %%
 new_pivot = student_data.pivot_table (index = 'class', columns = 'gender', values  ='score', aggfunc= 'mean')
new_pivot
# Out:
# gender  female  male
# class
# Eight      NaN  79.0
# Fifth      NaN  78.0
# Five       NaN  80.0
# Four      63.8  77.0
# Nine      65.0  18.0
# Seven     81.4  73.8
# Six       89.2  54.0
# Three      NaN  70.0

# %%
import numpy as np

conditions = [
       ( student_data ['score'] >= 85),
       ( student_data ['score'] >= 70) & ( student_data ['score'] <= 84),
       ( student_data ['score'] >= 60) & ( student_data ['score'] <= 69),
       ( student_data ['score'] < 60)
]

grades = ['A','B', 'C', 'D ']
student_data ['grade'] = np.select (conditions, grades, default= '')

student_data
# Out:
#     id         name  class  score  gender grade
# 0    1     John Deo   Four     75  female     B
# 1    2     Max Ruin  Three     85    male     A
# 2    3       Arnold  Three     55    male    D
# 3    4   Krish Star   Four     60  female     C
# 4    5    John Mike   Four     60  female     C
# 5    6    Alex John   Four     55    male    D
# 6    7  My John Rob  Fifth     78    male     B
# 7    8       Asruid   Five     85    male     A
# 8    9      Tes Qry    Six     78     NaN     B
# 9   10     Big John   Four     55  female    D
# 10  11       Ronald    Six     89  female     A
# 11  12        Recky    Six     94  female     A
# 12  13          Kty  Seven     88  female     A
# 13  14         Bigy  Seven     88  female     A
# 14  15     Tade Row    NaN     88    male     A
# 15  16        Gimmy   Four     88    male     A
# 16  17        Tumyu    Six     54    male    D
# 17  18        Honny   Five     75    male     B
# 18  19        Tinny   Nine     18    male    D
# ...

# %%
import numpy as np

student_data ['grade'] = np.where (student_data ['score'] >=85,'A',
                         np.where (student_data ['score'] >=70,'B',
                         np.where (student_data ['score'] >=60, 'C', 'D')))

student_data
# Out:
#     id         name  class  score  gender grade
# 0    1     John Deo   Four     75  female     B
# 1    2     Max Ruin  Three     85    male     A
# 2    3       Arnold  Three     55    male     D
# 3    4   Krish Star   Four     60  female     C
# 4    5    John Mike   Four     60  female     C
# 5    6    Alex John   Four     55    male     D
# 6    7  My John Rob  Fifth     78    male     B
# 7    8       Asruid   Five     85    male     A
# 8    9      Tes Qry    Six     78     NaN     B
# 9   10     Big John   Four     55  female     D
# 10  11       Ronald    Six     89  female     A
# 11  12        Recky    Six     94  female     A
# 12  13          Kty  Seven     88  female     A
# 13  14         Bigy  Seven     88  female     A
# 14  15     Tade Row    NaN     88    male     A
# 15  16        Gimmy   Four     88    male     A
# 16  17        Tumyu    Six     54    male     D
# 17  18        Honny   Five     75    male     B
# 18  19        Tinny   Nine     18    male     D
# ...

# %%
order_desc = student_data.sort_values (by = 'score', ascending= False )
order_desc
# Out:
#     id         name  class  score  gender grade
# 32  33    Kenn Rein    Six     96  female     A
# 11  12        Recky    Six     94  female     A
# 31  32    Binn Rott  Seven     90  female     A
# 10  11       Ronald    Six     89  female     A
# 30  31  Marry Toeey   Four     88    male     A
# 34  35   Rows Noump    Six     88  female     A
# 24  25     Giff Tow  Seven     88    male     A
# 14  15     Tade Row    NaN     88    male     A
# 15  16        Gimmy   Four     88    male     A
# 12  13          Kty  Seven     88  female     A
# 13  14         Bigy  Seven     88  female     A
# 27  28    Rojj Base  Seven     86  female     A
# 7    8       Asruid   Five     85    male     A
# 1    2     Max Ruin  Three     85    male     A
# 26  27          NaN  Three     81     NaN     B
# 29  30    Reppy Red    Six     79  female     B
# 25  26       Crelea  Seven     79    male     B
# 22  23        Herod  Eight     79    male     B
# 6    7  My John Rob  Fifth     78    male     B
# ...

# %%
order_desc = student_data.sort_values (by = 'score', ascending= False )
order_desc
# Out:
#     id         name  class  score  gender grade
# 32  33    Kenn Rein    Six     96  female     A
# 11  12        Recky    Six     94  female     A
# 31  32    Binn Rott  Seven     90  female     A
# 10  11       Ronald    Six     89  female     A
# 30  31  Marry Toeey   Four     88    male     A
# 34  35   Rows Noump    Six     88  female     A
# 24  25     Giff Tow  Seven     88    male     A
# 14  15     Tade Row    NaN     88    male     A
# 15  16        Gimmy   Four     88    male     A
# 12  13          Kty  Seven     88  female     A
# 13  14         Bigy  Seven     88  female     A
# 27  28    Rojj Base  Seven     86  female     A
# 7    8       Asruid   Five     85    male     A
# 1    2     Max Ruin  Three     85    male     A
# 26  27          NaN  Three     81     NaN     B
# 29  30    Reppy Red    Six     79  female     B
# 25  26       Crelea  Seven     79    male     B
# 22  23        Herod  Eight     79    male     B
# 6    7  My John Rob  Fifth     78    male     B
# ...

# %%
student_data ['class'].value_counts ()
# Out:
# class
# Seven    10
# Four      8
# Six       7
# Three     3
# Nine      2
# Five      2
# Fifth     1
# Eight     1
# Name: count, dtype: int64

# %%
round (student_data.groupby ('gender')['score'].mean(), 2)
# Out:
# gender
# female    77.31
# male      71.59
# Name: score, dtype: float64

# %%
student_data
# Out:
#     id         name  class  score  gender  passed
# 0    1     John Deo   Four     75  female    True
# 1    2     Max Ruin  Three     85    male    True
# 2    3       Arnold  Three     55    male   False
# 3    4   Krish Star   Four     60  female    True
# 4    5    John Mike   Four     60  female    True
# 5    6    Alex John   Four     55    male   False
# 6    7  My John Rob  Fifth     78    male    True
# 7    8       Asruid   Five     85    male    True
# 8    9      Tes Qry    Six     78     NaN    True
# 9   10     Big John   Four     55  female   False
# 10  11       Ronald    Six     89  female    True
# 11  12        Recky    Six     94  female    True
# 12  13          Kty  Seven     88  female    True
# 13  14         Bigy  Seven     88  female    True
# 14  15     Tade Row    NaN     88    male    True
# 15  16        Gimmy   Four     88    male    True
# 16  17        Tumyu    Six     54    male   False
# 17  18        Honny   Five     75    male    True
# ...

# %%
import matplotlib.pyplot as plt
plt.figure (figsize = (10, 6))
plt.hist(student_data['score'])
# Out:
# (array([ 1.,  0.,  0.,  0.,  6.,  2.,  3.,  8., 11.,  4.]),
#  array([18. , 25.8, 33.6, 41.4, 49.2, 57. , 64.8, 72.6, 80.4, 88.2, 96. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure (figsize = (10, 6))
plt.hist (student_data ['score'], edgecolor = 'white')
plt.title ('Histogram of Student Score')
# Out:
# Text(0.5, 1.0, 'Histogram of Student Score')

# %%
from google.colab import files
student_data = files.upload ()
# Out:
#      <input type="file" id="files-055fecf0-6925-42ed-998c-1390d1fbf3b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-055fecf0-6925-42ed-998c-1390d1fbf3b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
student_data= pd.read_csv ('student.csv')

# %%
student_data
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78     NaN
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
student_data.rename(columns={'mark': 'score'}, inplace=True)

# %%
student_data
# Out:
#     id         name  class  score  gender
# 0    1     John Deo   Four     75  female
# 1    2     Max Ruin  Three     85    male
# 2    3       Arnold  Three     55    male
# 3    4   Krish Star   Four     60  female
# 4    5    John Mike   Four     60  female
# 5    6    Alex John   Four     55    male
# 6    7  My John Rob  Fifth     78    male
# 7    8       Asruid   Five     85    male
# 8    9      Tes Qry    Six     78     NaN
# 9   10     Big John   Four     55  female
# 10  11       Ronald    Six     89  female
# 11  12        Recky    Six     94  female
# 12  13          Kty  Seven     88  female
# 13  14         Bigy  Seven     88  female
# 14  15     Tade Row    NaN     88    male
# 15  16        Gimmy   Four     88    male
# 16  17        Tumyu    Six     54    male
# 17  18        Honny   Five     75    male
# 18  19        Tinny   Nine     18    male
# 19  20       Jackly   Nine     65  female
# 20  21   Babby John   Four     69  female
# ...

# %%
numerical_data = student_data[['class','gender','score']]

# %%
numerical_data
# Out:
#     class  gender  score
# 0    Four  female     75
# 1   Three    male     85
# 2   Three    male     55
# 3    Four  female     60
# 4    Four  female     60
# 5    Four    male     55
# 6   Fifth    male     78
# 7    Five    male     85
# 8     Six     NaN     78
# 9    Four  female     55
# 10    Six  female     89
# 11    Six  female     94
# 12  Seven  female     88
# 13  Seven  female     88
# 14    NaN    male     88
# 15   Four    male     88
# 16    Six    male     54
# 17   Five    male     75
# 18   Nine    male     18
# 19   Nine  female     65
# 20   Four  female     69
# 21  Seven  female     55
# 22  Eight    male     79
# 23  Seven    male     78
# 24  Seven    male     88
# 25  Seven    male     79
# 26  Three     NaN     81
# 27  Seven  female     86
# 28  Seven    male     55
# 29    Six  female     79
# 30   Four    male     88
# 31  Seven  female     90
# 32    Six  female     96
# 33  Seven    male     69
# 34    Six  female     88

# %%
new_pivot = student_data.pivot_table (index = 'class',columns= 'gender', values = 'score',aggfunc = 'mean')

# %%
new_pivot
# Out:
# gender  female  male
# class
# Eight      NaN  79.0
# Fifth      NaN  78.0
# Five       NaN  80.0
# Four      63.8  77.0
# Nine      65.0  18.0
# Seven     81.4  73.8
# Six       89.2  54.0
# Three      NaN  70.0

# %%
order_desc = new_pivot.sort_values(by=['female', 'male'], ascending=False)

# %%
order_desc
# Out:
# gender  female  male
# class
# Six       89.2  54.0
# Seven     81.4  73.8
# Nine      65.0  18.0
# Four      63.8  77.0
# Five       NaN  80.0
# Eight      NaN  79.0
# Fifth      NaN  78.0
# Three      NaN  70.0

# %%
order_desc.reset_index().plot (x = 'class', y = ['female', 'male'], kind = 'bar')
# Out:
# <Axes: xlabel='class'>

# %%
order_desc.reset_index().plot (x = 'class', y = 'male', kind = 'scatter')
# Out:
# <Axes: xlabel='class', ylabel='male'>

# %%
import matplotlib.pyplot as plt
ax = order_desc.reset_index().plot(x='class', y='female', kind='scatter', label='Female Students')
order_desc.reset_index().plot(x='class', y='male', kind='scatter', ax=ax, color='red', label='Male Students')
plt.title('Female and Male Scores by Class')
plt.xlabel('Class')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
numerical_data.plot (x = 'class', y = 'score', kind = 'bar')
# Out:
# <Axes: xlabel='class'>

# %%
pivot_table = pd.pivot_table (student_data, values = 'score', index = 'class', aggfunc = 'mean')

# %%
pivot_table
# Out:
#            score
# class
# Eight  79.000000
# Fifth  78.000000
# Five   80.000000
# Four   68.750000
# Nine   41.500000
# Seven  77.600000
# Six    82.571429
# Three  73.666667

# %%
order_desc = pivot_table.sort_values (by = 'class', ascending= False )

# %%
order_desc
# Out:
#            score
# class
# Three  73.666667
# Six    82.571429
# Seven  77.600000
# Nine   41.500000
# Four   68.750000
# Five   80.000000
# Fifth  78.000000
# Eight  79.000000

# %%
import matplotlib.pyplot as plt
plt.figure (figsize = (8, 5))
plt.hist(order_desc['score'], color= 'orange',edgecolor = 'white' )
plt.title ('Histogram of Student Score')
# Out:
# Text(0.5, 1.0, 'Histogram of Student Score')

# %%
order_desc.reset_index ().plot (x='class', y='score', kind = 'bar', color = 'orange')
# Out:
# <Axes: xlabel='class'>

# %%
order_desc.reset_index ().plot (x='class', y='score', kind = 'bar', color = 'orange')
# Out:
# <Axes: xlabel='class'>

# %%
pivot_table.reset_index().plot (x='class', y= 'score', kind = 'bar')
# Out:
# <Axes: xlabel='class'>

# %%
numerical_data
# Out:
#     id  score
# 0    1     75
# 1    2     85
# 2    3     55
# 3    4     60
# 4    5     60
# 5    6     55
# 6    7     78
# 7    8     85
# 8    9     78
# 9   10     55
# 10  11     89
# 11  12     94
# 12  13     88
# 13  14     88
# 14  15     88
# 15  16     88
# 16  17     54
# 17  18     75
# 18  19     18
# 19  20     65
# 20  21     69
# 21  22     55
# 22  23     79
# 23  24     78
# 24  25     88
# 25  26     79
# 26  27     81
# 27  28     86
# 28  29     55
# 29  30     79
# 30  31     88
# 31  32     90
# 32  33     96
# 33  34     69
# 34  35     88

# %%
order_desc = numerical_data.sort_values (by = 'score', ascending= False )

# %%
order_desc
# Out:
#     class  gender  score
# 32    Six  female     96
# 11    Six  female     94
# 31  Seven  female     90
# 10    Six  female     89
# 30   Four    male     88
# 34    Six  female     88
# 24  Seven    male     88
# 14    NaN    male     88
# 15   Four    male     88
# 12  Seven  female     88
# 13  Seven  female     88
# 27  Seven  female     86
# 7    Five    male     85
# 1   Three    male     85
# 26  Three     NaN     81
# 29    Six  female     79
# 25  Seven    male     79
# 22  Eight    male     79
# 6   Fifth    male     78
# 23  Seven    male     78
# 8     Six     NaN     78
# 17   Five    male     75
# 0    Four  female     75
# 33  Seven    male     69
# 20   Four  female     69
# 19   Nine  female     65
# 3    Four  female     60
# 4    Four  female     60
# 2   Three    male     55
# 5    Four    male     55
# 9    Four  female     55
# 21  Seven  female     55
# 28  Seven    male     55
# 16    Six    male     54
# 18   Nine    male     18

# %%
order_desc.reset_index ().plot (x= group by'class', y='score', kind = 'bar', color = 'orange')
# Out:
# <Axes: xlabel='class'>

# %%
pivot_table.reset_index().plot (x = 'class', y = 'score', kind = 'scatter')
# Out:
# <Axes: xlabel='class', ylabel='score'>

# %%
corr_matrix = numerical_data.corr ()
corr_matrix
# Out:
#              id     score
# id     1.000000  0.211582
# score  0.211582  1.000000

# %%
import seaborn as sns
plt.figure (figsize = (5, 2))
sns.heatmap (corr_matrix ,annot=True)
# Out:
# <Axes: >
